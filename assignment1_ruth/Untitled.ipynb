# %%
import pandas as pd

# %%
df = pd.read_csv('../DataMining/RuthsList.csv')

# %%
df = df.dropna()

# %%
df.isnull().sum().plot('bar', color='blue')

# %%
mean(4,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d112dfdd49ad> in <module>()
# ----> 1 mean(4,3)
#
# NameError: name 'mean' is not defined

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'activity', 'appCat.builtin_count', 'appCat.builtin_sum',
#        'appCat.communication_count', 'appCat.communication_sum',
#        'appCat.entertainment_count', 'appCat.entertainment_sum',
#        'appCat.finance_count', 'appCat.finance_sum', 'appCat.game_count',
#        'appCat.game_sum', 'appCat.office_count', 'appCat.office_sum',
#        'appCat.other_count', 'appCat.other_sum', 'appCat.social_count',
#        'appCat.social_sum', 'appCat.travel_count', 'appCat.travel_sum',
#        'appCat.unknown_count', 'appCat.unknown_sum', 'appCat.utilities_count',
#        'appCat.utilities_sum', 'appCat.weather_count', 'appCat.weather_sum',
#        'call', 'circumplex.arousal', 'circumplex.valence', 'id', 'mood',
#        'screen_count', 'screen_sum', 'sms'],
#       dtype='object')

# %%
df[df.id == 'AS14.01'].sort_values('Unnamed: 0')
# Out:
#                        Unnamed: 0  activity  appCat.builtin_count  \
# 0   2014-02-17 00:00:00.000000000       NaN                   NaN
# 1   2014-02-18 00:00:00.000000000       NaN                   NaN
# 2   2014-02-19 00:00:00.000000000       NaN                   NaN
# 3   2014-02-20 00:00:00.000000000       NaN                   NaN
# 4   2014-02-21 00:00:00.000000000       NaN                   NaN
# 5   2014-02-22 00:00:00.000000000       NaN                   NaN
# 6   2014-02-23 00:00:00.000000000       NaN                   NaN
# 7   2014-02-24 00:00:00.000000000       NaN                   NaN
# 8   2014-02-25 00:00:00.000000000       NaN                   NaN
# 9   2014-02-26 00:00:00.000000000       NaN                   NaN
# 10  2014-02-27 00:00:00.000000000       NaN                   NaN
# 11  2014-02-28 00:00:00.000000000       NaN                   NaN
# 12  2014-03-01 00:00:00.000000000       NaN                   NaN
# ...
